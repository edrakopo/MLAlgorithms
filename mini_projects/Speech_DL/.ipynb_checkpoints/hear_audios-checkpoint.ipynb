# %%
import pandas as pd
import os
import math
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

fname1 = 'speech-accent-archive/recordings/recordings/' + 'afrikaans1.mp3'
ipd.Audio(fname1)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fname2 = 'speech-accent-archive/recordings/recordings/' + 'mandarin46.mp3'
ipd.Audio(fname2)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#choose to listen to a male voice. 
#print(df.groupby("filename")['sex'].describe().head(10))
fname3 = 'speech-accent-archive/recordings/recordings/' + 'agni1.mp3'   
ipd.Audio(fname3)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#choose to hear the US Southern Accent. 
#print(df[df['birthplace'].str.contains("kentucky",na=False)])
fname4 = 'speech-accent-archive/recordings/recordings/' + 'english385.mp3'   
ipd.Audio(fname4)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
